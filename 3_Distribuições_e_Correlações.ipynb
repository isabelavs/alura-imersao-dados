# %% [markdown]
# <a href="https://colab.research.google.com/github/isabelavs/alura-imersao-dados/blob/main/3_Distribui%C3%A7%C3%B5es_e_Correla%C3%A7%C3%B5es.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Aula 3

# %%
import pandas as pd

fonte = "https://github.com/alura-cursos/imersao-dados-2-2020/blob/master/MICRODADOS_ENEM_2019_SAMPLE_43278.csv?raw=true"

dados = pd.read_csv(fonte)

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
provas = ["NU_NOTA_REDACAO", "NU_NOTA_CN", "NU_NOTA_CH", "NU_NOTA_MT", "NU_NOTA_LC"]

dados["NU_NOTA_TOTAL"] = dados[provas].sum(axis = 1)

# %%
dados_sem_notas_zero = dados.query("NU_NOTA_TOTAL != 0")

plt.figure(figsize = (12, 8))
sns.histplot(dados_sem_notas_zero, x = "NU_NOTA_TOTAL")

# %%
plt.figure(figsize = (12, 8))
sns.histplot(dados_sem_notas_zero, x = "NU_NOTA_MT")

# %%
plt.figure(figsize = (12, 8))
sns.histplot(dados_sem_notas_zero, x = "NU_NOTA_LC")

# %%
plt.figure(figsize = (12, 8))
sns.histplot(dados_sem_notas_zero, x = "NU_NOTA_TOTAL", hue = "Q025", kde = True)

# %%
plt.figure(figsize = (12, 8))
sns.histplot(dados_sem_notas_zero, x = "NU_NOTA_TOTAL", hue = "Q025", kde = True, stat = "density")

# %%
plt.figure(figsize = (12, 8))
sns.histplot(dados_sem_notas_zero, x = "NU_NOTA_TOTAL", hue = "Q025", kde = True, stat = "probability")

# %%
plt.figure(figsize = (12, 8))
sns.histplot(dados_sem_notas_zero, x = "NU_NOTA_TOTAL", hue = "Q025", kde = True, stat = "probability", cumulative=True)

# %%
plt.figure(figsize = (12, 8))
sns.histplot(dados_sem_notas_zero, x = "NU_NOTA_TOTAL", hue = "Q025", kde = True, stat = "density", cumulative=True)

# %%
plt.figure(figsize=(12, 12))
sns.scatterplot(data = dados_sem_notas_zero, x="NU_NOTA_MT", y="NU_NOTA_LC", hue="Q025")
plt.xlim((-50, 1050))
plt.ylim((-50, 1050))
# Out:
# (-50.0, 1050.0)

# %%
sns.pairplot(data = dados_sem_notas_zero[provas])

# %%
correlacao = dados_sem_notas_zero[provas].corr()
correlacao
# Out:
#                  NU_NOTA_REDACAO  NU_NOTA_CN  ...  NU_NOTA_MT  NU_NOTA_LC
# NU_NOTA_REDACAO         1.000000    0.504740  ...    0.493046    0.535797
# NU_NOTA_CN              0.504740    1.000000  ...    0.649527    0.641624
# NU_NOTA_CH              0.528338    0.668979  ...    0.610332    0.744170
# NU_NOTA_MT              0.493046    0.649527  ...    1.000000    0.587710
# NU_NOTA_LC              0.535797    0.641624  ...    0.587710    1.000000
#
# [5 rows x 5 columns]

# %%
sns.heatmap(correlacao, cmap="Blues", center=0.4, annot=True)

# %% [markdown]
# Desafio 01: Plotar no mesmo gráfico (MT e LC) a moda, média e mediana (matplotlib linha vertical).
#
# Desafio 02: Melhorar a matriz de correlação deixando o plot na diagonal.
#
# Desafio 03: Filtrar as notas do estado/cidade e rodar esses gráficos, vendo se apresentam os histogramas de nota apresentam um comportamento similar ao do Brasil inteiro.
#
# Desafio 05: Refletir sobre a correlação entre MT e LC.
